# %%
import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
from sklearn import preprocessing
from math import isnan
import datetime as dt
from datetime import datetime
from datetime import timedelta

# %%
file = 'cleanDataFinal-yifeng.csv'
myData = pd.read_csv(file)

# %% [markdown]
# # Delete unrelated attribute

# %%
myData.head(5)
# Out:
#    Unnamed: 0     Cardnum        Date       Merchnum        Merch description  \
# 0           0  5142190439  2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
# 1           1  5142183973  2010-01-01    61003026333  SERVICE MERCHANDISE #81
# 2           2  5142131721  2010-01-01  4503082993600        OFFICE DEPOT #191
# 3           3  5142148452  2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#
# 4           4  5142190439  2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
#
#   Merch state  Merch zip Transtype  Amount  Fraud
# 0          TN    38118.0         P    3.62      0
# 1          MA     1803.0         P   31.42      0
# 2          MD    20706.0         P  178.49      0
# 3          TN    38118.0         P    3.62      0
# 4          TN    38118.0         P    3.62      0

# %%
del_attribute = 'Unnamed: 0'

# %%
myData.drop([del_attribute],axis = 1, inplace = True)

# %%
myData.head(5)
# Out:
#       Cardnum        Date       Merchnum        Merch description Merch state  \
# 0  5142190439  2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#          TN
# 1  5142183973  2010-01-01    61003026333  SERVICE MERCHANDISE #81          MA
# 2  5142131721  2010-01-01  4503082993600        OFFICE DEPOT #191          MD
# 3  5142148452  2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#          TN
# 4  5142190439  2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#          TN
#
#    Merch zip Transtype  Amount  Fraud
# 0    38118.0         P    3.62      0
# 1     1803.0         P   31.42      0
# 2    20706.0         P  178.49      0
# 3    38118.0         P    3.62      0
# 4    38118.0         P    3.62      0

# %% [markdown]
# # Differenciate Date

# %%
def str_to_datetime (x):
    return datetime.strptime(x, '%Y-%m-%d')

# %%
myData['Date'] = myData['Date'].apply(str_to_datetime)

# %%
temp_date = myData.iloc[0,1]
temp_delta = dt.timedelta(0,0,0)

# %%
def sameDay_plus1sec (x):
    global temp_date 
    global temp_delta
    if x['Date'] == temp_date:
        temp_delta = temp_delta + dt.timedelta(0,1,0)
        return (temp_delta + x['Date'])
    else:
        temp_date = x['Date']
        temp_delta = dt.timedelta(0,1,0)
        return (temp_delta + x['Date'])

# %%
myData['Date'] = myData.apply(sameDay_plus1sec, axis = 1)

# %%
myData.set_index('Date', inplace= True)

# %%
myData.head(2)
# Out:
#                         Cardnum       Merchnum        Merch description  \
# Date
# 2010-01-01 00:00:01  5142190439  5509006296254   FEDEX SHP 12/23/09 AB#
# 2010-01-01 00:00:02  5142183973    61003026333  SERVICE MERCHANDISE #81
#
#                     Merch state  Merch zip Transtype  Amount  Fraud
# Date
# 2010-01-01 00:00:01          TN    38118.0         P    3.62      0
# 2010-01-01 00:00:02          MA     1803.0         P   31.42      0

# %% [markdown]
# # Begin Feature Engineering

# %%
myData.iloc[6666,]
# Out:
# Cardnum                            5142189945
# Merchnum                        2094206450006
# Merch description    VWR SCIENTIFIC PROD VCTS
# Merch state                                PA
# Merch zip                               19380
# Transtype                                   P
# Amount                                 576.61
# Fraud                                       0
# Name: 2010-01-31 00:02:09, dtype: object

# %%
myData.head(4)
# Out:
#                         Cardnum       Merchnum        Merch description  \
# Date
# 2010-01-01 00:00:01  5142190439  5509006296254   FEDEX SHP 12/23/09 AB#
# 2010-01-01 00:00:02  5142183973    61003026333  SERVICE MERCHANDISE #81
# 2010-01-01 00:00:03  5142131721  4503082993600        OFFICE DEPOT #191
# 2010-01-01 00:00:04  5142148452  5509006296254   FEDEX SHP 12/28/09 AB#
#
#                     Merch state  Merch zip Transtype  Amount  Fraud
# Date
# 2010-01-01 00:00:01          TN    38118.0         P    3.62      0
# 2010-01-01 00:00:02          MA     1803.0         P   31.42      0
# 2010-01-01 00:00:03          MD    20706.0         P  178.49      0
# 2010-01-01 00:00:04          TN    38118.0         P    3.62      0

# %% [markdown]
# ## 0 days: all attributes

# %%
def allAttributes_0 (temp_datetime):
  
    temp_year = temp_datetime.year
    temp_month = temp_datetime.month
    temp_day = temp_datetime.day
    temp_hour = temp_datetime.hour
    temp_minute = temp_datetime.minute
    temp_second = temp_datetime.second
    
    temp_begin = str(temp_month) + '/' + str(temp_day) + '/' + str(temp_year)  \
            +' ' +'00:00'

    temp_end = str(temp_month) + '/' + str(temp_day) + '/' + str(temp_year)  \
            +' ' + str(temp_hour) + ':' + str(temp_minute) + ":" + str(temp_second)
    
    temp0_df = myData.loc[temp_begin:temp_end].copy()
    
    #---------------------------------new attributes for this card------------------------------------------
    
    groupCardnum = temp0_df.groupby(['Cardnum'])
    temp_instance_Cardnum = myData.loc[temp_datetime, 'Cardnum']
    
    '''
    groupCardnum = temp0_df[['Cardnum','Amount']].groupby(['Cardnum']).mean().copy()
    temp_instance_Cardnum = myData.loc[temp_datetime, 'Cardnum']
    myData.loc[temp_datetime, 'Average/Card-0days'] = groupCardnum.loc[temp_instance_Cardnum, 'Amount']
    '''
    
    temp_df = groupCardnum.max().copy()
    
    #print(temp_df.loc[temp_instance_Cardnum, 'Amount'])
    
    myData.loc[temp_datetime, 'Count-0days'] = temp_df.loc[temp_instance_Cardnum, 'Amount']

    #---------------------------------new attributes for this card------------------------------------------

# %% [markdown]
# 0:03:33.169348

# %% [markdown]
# 0:04:14.908239

# %%
start_time = dt.datetime.now()
test_count = 1
for i in myData.index:
    test_count = test_count + 1
    if test_count > 1000:
        break
    allAttributes_0(i)
end_time = dt.datetime.now()
print(end_time-start_time)
# Out:
# 0:01:44.041192

# %%
0:01:44.041192 max

# %%
0:01:35.336651 min

# %%
0:00:03.050314 mean

# %%
0:00:02.898242 count

# %%
0:00:03.136647 sum

# %%
myData.T
# Out:
# Date                   2010-01-01 00:00:01      2010-01-01 00:00:02  \
# Cardnum                         5142190439               5142183973
# Merchnum                     5509006296254              61003026333
# Merch description   FEDEX SHP 12/23/09 AB#  SERVICE MERCHANDISE #81
# Merch state                             TN                       MA
# Merch zip                            38118                     1803
# Transtype                                P                        P
# Amount                                3.62                    31.42
# Fraud                                    0                        0
# Average/Card-0days                    3.62                    31.42
# Max/Card-0days                        3.62                    31.42
# Count-0days                              1                        1
#
# Date               2010-01-01 00:00:03     2010-01-01 00:00:04  \
# Cardnum                     5142131721              5142148452
# Merchnum                 4503082993600           5509006296254
# Merch description    OFFICE DEPOT #191  FEDEX SHP 12/28/09 AB#
# Merch state                         MD                      TN
# Merch zip                        20706                   38118
# Transtype                            P                       P
# Amount                          178.49                    3.62
# Fraud                                0                       0
# Average/Card-0days              178.49                    3.62
# Max/Card-0days                  178.49                    3.62
# Count-0days                          1                       1
#
# Date                   2010-01-01 00:00:05     2010-01-01 00:00:06  \
# Cardnum                         5142190439              5142149874
# Merchnum                     5509006296254           5509006296254
# Merch description   FEDEX SHP 12/23/09 AB#  FEDEX SHP 12/22/09 AB#
# Merch state                             TN                      TN
# Merch zip                            38118                   38118
# Transtype                                P                       P
# Amount                                3.62                    3.67
# Fraud                                    0                       0
# Average/Card-0days                    3.62                    3.67
# Max/Card-0days                        3.62                    3.67
# Count-0days                              2                       1
#
# Date                   2010-01-01 00:00:07    2010-01-01 00:00:08  \
# Cardnum                         5142189277             5142191182
# Merchnum                     5509006296254          6098208200062
# Merch description   FEDEX SHP 12/28/09 AB#  MIAMI COMPUTER SUPPLY
# Merch state                             TN                     OH
# Merch zip                            38118                  45429
# Transtype                                P                      P
# Amount                                3.62                 230.32
# Fraud                                    0                      0
# Average/Card-0days                    3.62                 230.32
# Max/Card-0days                        3.62                 230.32
# Count-0days                              1                      1
#
# Date               2010-01-01 00:00:09     2010-01-01 00:00:10  \
# Cardnum                     5142258629              5142190439
# Merchnum                  602608969534           5509006296254
# Merch description       FISHER SCI ATL  FEDEX SHP 12/23/09 AB#
# Merch state                         GA                      TN
# Merch zip                        30091                   38118
# Transtype                            P                       P
# Amount                           62.11                    3.62
# Fraud                                0                       0
# Average/Card-0days               62.11                    3.62
# Max/Card-0days                   62.11                    3.62
# Count-0days                          1                       3
#
# Date                        ...           2010-12-31 00:00:43  \
# Cardnum                     ...                    5142187448
# Merchnum                    ...                 5725000466504
# Merch description           ...            CDW*GOVERNMENT INC
# Merch state                 ...                            IL
# Merch zip                   ...                         60061
# Transtype                   ...                             P
# Amount                      ...                       2231.08
# Fraud                       ...                             0
# Average/Card-0days          ...                       2231.08
# Max/Card-0days              ...                           NaN
# Count-0days                 ...                             1
#
# Date                     2010-12-31 00:00:44 2010-12-31 00:00:45  \
# Cardnum                           5142160778          5142226979
# Merchnum                       08-0616075333        602608969534
# Merch description   COMPUTER STORE OF CORVLS      FISHER SCI ATL
# Merch state                               OR                  GA
# Merch zip                              97330               30091
# Transtype                                  P                   P
# Amount                                243.15               32.04
# Fraud                                      1                   0
# Average/Card-0days                   132.955               98.52
# Max/Card-0days                           NaN                 NaN
# Count-0days                                2                   2
#
# Date               2010-12-31 00:00:46 2010-12-31 00:00:47  \
# Cardnum                     5142196337          5142221253
# Merchnum                  467619770330       5725000466504
# Merch description          STAY ONLINE  CDW*GOVERNMENT INC
# Merch state                         NC                  IL
# Merch zip                        27560               60061
# Transtype                            P                   P
# Amount                          147.35                 425
# Fraud                                0                   0
# Average/Card-0days              147.35             1022.18
# Max/Card-0days                     NaN                 NaN
# Count-0days                          1                   3
#
# Date                   2010-12-31 00:00:48     2010-12-31 00:00:49  \
# Cardnum                         5142276053              5142225701
# Merchnum                     3500000006160           8090710030950
# Merch description   BEST BUY      00001610  MARKUS OFFICE SUPPLIES
# Merch state                             KY                      OH
# Merch zip                            41042                   45248
# Transtype                                P                       P
# Amount                               84.79                  118.75
# Fraud                                    0                       0
# Average/Card-0days                   84.79                 401.875
# Max/Card-0days                         NaN                     NaN
# Count-0days                              1                       2
#
# Date               2010-12-31 00:00:50 2010-12-31 00:00:51  \
# Cardnum                     5142226486          5142244619
# Merchnum                 4503057341100       8834000695412
# Merch description        TECH PAC, INC             BUY.COM
# Merch state                         OH                  CA
# Merch zip                        45150               92656
# Transtype                            P                   P
# Amount                          363.56             2202.03
# Fraud                                0                   0
# Average/Card-0days              363.56             2202.03
# Max/Card-0days                     NaN                 NaN
# Count-0days                          1                   1
#
# Date                  2010-12-31 00:00:52
# Cardnum                        5142243247
# Merchnum                    9108347680006
# Merch description   STAPLES NATIONAL #471
# Merch state                            NJ
# Merch zip                            7606
# Transtype                               P
# Amount                             554.64
# Fraud                                   0
# Average/Card-0days                 554.64
# Max/Card-0days                        NaN
# Count-0days                             1
#
# [11 rows x 96366 columns]

# %% [markdown]
# # maybe it is the time to choose another approach

# %% [markdown]
# # too many resoures are wasted if we do index by index

# %% [markdown]
# # on the other hand, what if we first choose to subset the whole dataframe

# %% [markdown]
# # all the records for a same card is selected

# %%
test1 = '2010-09-20 00:07:10'

# %%
test_instance = datetime.strptime(test1, '%Y-%m-%d %H:%M:%S')
test_instance
# Out:
# datetime.datetime(2010, 9, 20, 0, 7, 10)

# %%
temp_datetime = test_instance
temp_year = temp_datetime.year
temp_month = temp_datetime.month
temp_day = temp_datetime.day
temp_hour = temp_datetime.hour
temp_minute = temp_datetime.minute
temp_second = temp_datetime.second

temp_begin = str(temp_month) + '/' + str(temp_day) + '/' + str(temp_year)  \
        +' ' +'00:00'

temp_end = str(temp_month) + '/' + str(temp_day) + '/' + str(temp_year)  \
        +' ' + str(temp_hour) + ':' + str(temp_minute) + ":" + str(temp_second)

temp0_df = myData.loc[temp_begin:temp_end].copy()

#---------------------------------new attributes for this card------------------------------------------
groupCardnum = temp0_df[['Cardnum','Amount']].groupby(['Cardnum']).mean().copy()
temp_instance_Cardnum = myData.loc[temp_datetime, 'Cardnum']
myData.loc[temp_datetime, 'Average/Card-0days'] = groupCardnum.loc[temp_instance_Cardnum, 'Amount']

groupCardnum = temp0_df.groupby(['Cardnum']).max().copy()
temp_instance_Cardnum = myData.loc[temp_datetime, 'Cardnum']
myData.loc[temp_datetime, 'Max/Card-0days'] = groupCardnum.loc[temp_instance_Cardnum, 'Amount']

#---------------------------------new attributes for this card------------------------------------------

# %%
temp0_df.loc[test_instance]
# Out:
# Cardnum                           5142152613
# Merchnum                       4353000719908
# Merch description     AMAZON.COM  *SUPERSTOR
# Merch state                               WA
# Merch zip                              98101
# Transtype                                  P
# Amount                                335.83
# Fraud                                      0
# Average/Card-0days                    187.31
# Max/Card-0days                        335.83
# Name: 2010-09-20 00:07:10, dtype: object

# %%
temp0_df[temp0_df['Cardnum'] ==  5142152613]
# Out:
#                         Cardnum       Merchnum         Merch description  \
# Date
# 2010-09-20 00:00:36  5142152613  6880062529835  MILLER'S OFFICE PRODUCTS
# 2010-09-20 00:04:25  5142152613  9108234610000              STAPLES #941
# 2010-09-20 00:07:10  5142152613  4353000719908    AMAZON.COM  *SUPERSTOR
#
#                     Merch state  Merch zip Transtype  Amount  Fraud  \
# Date
# 2010-09-20 00:00:36          VA    22150.0         P   12.20      0
